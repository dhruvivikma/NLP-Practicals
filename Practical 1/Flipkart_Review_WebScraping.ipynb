# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.flipkart.com/kadence-concert-ukulele/product-reviews/itmeq9kyyktke8yy?pid=UKEEQ9JUYPVEPYGH&lid=LSTUKEEQ9JUYPVEPYGHKB4XCA&marketplace=FLIPKART&page='


for i in range(1,11):
  url_no = url + str(i)
  html_text = requests.get(url_no).text
  soup = BeautifulSoup(html_text, 'html.parser')
  rev = soup.find_all('div', class_ = '_2c2kV-')
  rev2 = rev2 + soup.find_all('div', class_ = 't-ZTKy')
  rat = soup.find_all('div', class_ = '_3LWZlK _1BLPMq')

   
  

for i in rev2:
  print(i.text.replace('READ MORE',''),"\n")


'''
rat = soup.find_all('div', class_ = '_3LWZlK _1BLPMq')
for i in rat:
  print(i.text)
'''
# Out:
# Super...loved it...
#
# It is really good. But sadly they didn't send me the equaliser. Sound quality is more or less good. And stays in tune for long.
#
# Awesome instrument. Has great build quality and great sound quality too. One of the best ukelele on Flipkart
#
# Quality is good
#
# Very nice product
#
# I really love this,,
#
# The Uke is very good but the cover received with that is a very bad quality product. And also has unfinished ends.
#
# good product
#
# Nice product and delivered in time with good packing.. Worth the price
#
# Its really good sounds good ,looks good but the tuner given to you doesn't work 🤣
#
# first of all, thanks to flipkart for faster delivery..product is delivered 4 days early that too in as small town of seoni.nice product, worth it.i have gifted it to someone special.She is so happy..
#
# ...
